# %% [markdown]
# <a href="https://colab.research.google.com/github/Mainabryan/100-days-challenge-for-machine-learning-practise/blob/main/Speech_Recognition_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# !pip install speechrecognition
# !pip install pydub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 54.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 66.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 52.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Speech Recognition App**

# %%
from pydub import AudioSegment
from google.colab import files
import speech_recognition as sr

# Step 1: Upload the audio file
uploaded = files.upload()

# Step 2: Convert the uploaded file to WAV
def convert_to_wav(uploaded_file_dict):
    for filename in uploaded_file_dict.keys():
        # Load the uploaded audio file
        audio = AudioSegment.from_file(filename)

        # Export it as WAV format
        wav_filename = filename.split('.')[0] + ".wav"
        audio.export(wav_filename, format="wav")
        print(f"Converted {filename} to {wav_filename}")

        return wav_filename

# Step 3: Transcribe the WAV file using speech recognition
def transcribe_audio_file(wav_filename):
    r = sr.Recognizer()

    with sr.AudioFile(wav_filename) as source:
        audio_data = r.record(source)
        try:
            text = r.recognize_google(audio_data)
            return text
        except:
            return "Sorry, I could not understand the audio."

# Step 4: Run the conversion and transcription
wav_filename = convert_to_wav(uploaded)
text_output = transcribe_audio_file(wav_filename)
print("Transcription:", text_output)
# Out:
#      <input type="file" id="files-f5930d64-778f-427c-b846-0f21c9b90eda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5930d64-778f-427c-b846-0f21c9b90eda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **STREAMLIT DEPLOYMENT VERSION**

# %%
# Installing the required packages
# !pip install streamlit           # Streamlit is a framework to create web apps for machine learning models
# !pip install pyngrok             # Pyngrok is used to expose the local Streamlit app to the web via a public URL
# !pip install streamlit-option-menu # Option menu for creating navigation in the app
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.3/829.3 kB 11.2 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py
import streamlit as st
from pydub import AudioSegment
import speech_recognition as sr

# Define the main function to encapsulate the conversion and transcription logic
def main():
    st.title("Audio Transcription App")

    # Step 1: Upload the audio file
    uploaded_file = st.file_uploader("Upload an audio file", type=["mp3", "wav", "ogg", "flac", "m4a"])

    if uploaded_file is not None:
        # Step 2: Convert the uploaded file to WAV
        def convert_to_wav(uploaded_file):
            # Load the uploaded audio file
            audio = AudioSegment.from_file(uploaded_file)

            # Export it as WAV format
            wav_file_name = "converted_audio.wav"
            audio.export(wav_file_name, format="wav")
            st.success(f"Converted to {wav_file_name}")

            return wav_file_name

        # Step 3: Transcribe the WAV file using speech recognition
        def transcribe_audio_file(wav_file_name):
            r = sr.Recognizer()

            with sr.AudioFile(wav_file_name) as source:
                audio_data = r.record(source)
                try:
                    text = r.recognize_google(audio_data)
                    return text
                except sr.UnknownValueError:
                    return "Sorry, I could not understand the audio."
                except sr.RequestError:
                    return "Sorry, there was an error with the request."

        # Step 4: Run the conversion and transcription
        wav_file_name = convert_to_wav(uploaded_file)
        text_output = transcribe_audio_file(wav_file_name)
        st.write("Transcription:", text_output)

# Step 5: Run the App
if __name__ == "__main__": # Corrected the typographical error in the if statement
    main() # Call the defined main function
# Out:
# Writing app.py

# %%
! wget -q -O - ipv4.icanhazip.com
# Out:
# 35.247.108.199

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹⠸⠼⠴⠦⠧
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.247.108.199:8501
#
# ⠇⠏⠋⠙⠹⠸⠼⠴⠦Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼your url is: https://wise-emus-give.loca.lt
