# %% [markdown]
# <a href="https://colab.research.google.com/github/Mainabryan/100-days-challenge-for-machine-learning-practise/blob/main/heart_attack_(decision_tree_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## HEART CLEVALAND (attack)

# %% [markdown]
# # import the necessary libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# # load the dataset

# %%
# load the dataset
data = pd.read_csv('/content/heart_cleveland_upload.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  condition
# 0   69    1   0       160   234  ...      0.1      1   1     0          0
# 1   69    0   0       140   239  ...      1.8      0   2     0          0
# 2   66    0   0       150   226  ...      2.6      2   0     0          0
# 3   65    1   0       138   282  ...      1.4      1   1     0          1
# 4   64    1   0       110   211  ...      1.8      1   0     0          0
#
# [5 rows x 14 columns]

# %% [markdown]
# # preprocesing

# %%
# Features and target
x = data.drop('condition', axis=1)
y = data['condition']

# %%
print(data.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'condition'],
#       dtype='object')

# %% [markdown]
# # split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Train model

# %%
model = DecisionTreeClassifier(max_depth=4)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# # Predict and check accuracy

# %%
pred = model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.6333333333333333

# %% [markdown]
# # visualize

# %%
plt.figure(figsize=(18, 8))
plot_tree(model, feature_names=x.columns, class_names=["No Disease", "Disease"], filled=True)
plt.show()

# %%
from sklearn.tree import plot_tree
